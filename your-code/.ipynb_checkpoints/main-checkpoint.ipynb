# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# Import numpy and pandas
import numpy as np
import pandas as pd

# %% [markdown]
# # Challenge 1 - Loading and Evaluating The Data
#
# In this lab, we will look at a dataset of sensor data from a cellular phone. The phone was carried in the subject's pocket for a few minutes while they walked around.
#
# To load the data, run the code below.

# %%
# Run this code:

sensor = pd.read_csv('../sub_1.csv')
sensor.drop(columns=['Unnamed: 0'], inplace=True)

# %% [markdown]
# Examine the data using the `head` function.

# %%
# Your code here:

sensor.head()
# Out:
#    attitude.roll  attitude.pitch  attitude.yaw  gravity.x  gravity.y  \
# 0       1.528132       -0.733896      0.696372   0.741895   0.669768
# 1       1.527992       -0.716987      0.677762   0.753099   0.657116
# 2       1.527765       -0.706999      0.670951   0.759611   0.649555
# 3       1.516768       -0.704678      0.675735   0.760709   0.647788
# 4       1.493941       -0.703918      0.672994   0.760062   0.647210
#
#    gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# 0  -0.031672        0.316738        0.778180        1.082764
# 1  -0.032255        0.842032        0.424446        0.643574
# 2  -0.032707       -0.138143       -0.040741        0.343563
# 3  -0.041140       -0.025005       -1.048717        0.035860
# 4  -0.058530        0.114253       -0.912890        0.047341
#
#    userAcceleration.x  userAcceleration.y  userAcceleration.z
# 0            0.294894           -0.184493            0.377542
# ...

# %% [markdown]
# Check whether there is any missing data. If there is any missing data, remove the rows containing missing data.

# %%
# Your code here:

sensor.isnull().sum()
# Out:
# attitude.roll         0
# attitude.pitch        0
# attitude.yaw          0
# gravity.x             0
# gravity.y             0
# gravity.z             0
# rotationRate.x        0
# rotationRate.y        0
# rotationRate.z        0
# userAcceleration.x    0
# userAcceleration.y    0
# userAcceleration.z    0
# dtype: int64

# %% [markdown]
# How many rows and columns are in our data?

# %%
# Your code here:
sensor.info()
# 1,751 rows
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1751 entries, 0 to 1750
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   attitude.roll       1751 non-null   float64
#  1   attitude.pitch      1751 non-null   float64
#  2   attitude.yaw        1751 non-null   float64
#  3   gravity.x           1751 non-null   float64
#  4   gravity.y           1751 non-null   float64
#  5   gravity.z           1751 non-null   float64
#  6   rotationRate.x      1751 non-null   float64
#  7   rotationRate.y      1751 non-null   float64
#  8   rotationRate.z      1751 non-null   float64
#  9   userAcceleration.x  1751 non-null   float64
#  10  userAcceleration.y  1751 non-null   float64
#  11  userAcceleration.z  1751 non-null   float64
# dtypes: float64(12)
# memory usage: 164.2 KB

# %% [markdown]
# To perform time series analysis on the data, we must change the index from a range index to a time series index. In the cell below, create a time series index using the `pd.date_range` function. Create a time series index starting at 1/1/2018 00:00:00 and ending at 1/1/2018 00:29:10. The number of periods is equal to the number of rows in `sensor`. The frequency should be set to `infer`.

# %%
# Your code here:
sensor['time'] = pd.date_range(start = '1/1/2018 00:00:00', end = '1/1/2018 00:29:10', freq = 'S')
sensor.head()
# Out:
#    attitude.roll  attitude.pitch  attitude.yaw  gravity.x  gravity.y  \
# 0       1.528132       -0.733896      0.696372   0.741895   0.669768
# 1       1.527992       -0.716987      0.677762   0.753099   0.657116
# 2       1.527765       -0.706999      0.670951   0.759611   0.649555
# 3       1.516768       -0.704678      0.675735   0.760709   0.647788
# 4       1.493941       -0.703918      0.672994   0.760062   0.647210
#
#    gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# 0  -0.031672        0.316738        0.778180        1.082764
# 1  -0.032255        0.842032        0.424446        0.643574
# 2  -0.032707       -0.138143       -0.040741        0.343563
# 3  -0.041140       -0.025005       -1.048717        0.035860
# 4  -0.058530        0.114253       -0.912890        0.047341
#
#    userAcceleration.x  userAcceleration.y  userAcceleration.z  \
# 0            0.294894           -0.184493            0.377542
# ...

# %% [markdown]
# Assign the time series index to the dataframe's index.

# %%
# Your code here:
sensor.set_index('time', inplace = True)
sensor.head()
# Out:
#                      attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# time
# 2018-01-01 00:00:00       1.528132       -0.733896      0.696372   0.741895
# 2018-01-01 00:00:01       1.527992       -0.716987      0.677762   0.753099
# 2018-01-01 00:00:02       1.527765       -0.706999      0.670951   0.759611
# 2018-01-01 00:00:03       1.516768       -0.704678      0.675735   0.760709
# 2018-01-01 00:00:04       1.493941       -0.703918      0.672994   0.760062
#
#                      gravity.y  gravity.z  rotationRate.x  rotationRate.y  \
# time
# 2018-01-01 00:00:00   0.669768  -0.031672        0.316738        0.778180
# 2018-01-01 00:00:01   0.657116  -0.032255        0.842032        0.424446
# 2018-01-01 00:00:02   0.649555  -0.032707       -0.138143       -0.040741
# 2018-01-01 00:00:03   0.647788  -0.041140       -0.025005       -1.048717
# 2018-01-01 00:00:04   0.647210  -0.058530        0.114253       -0.912890
#
# ...

# %% [markdown]
# Our next step is to decompose the time series and evaluate the patterns in the data. Load the `statsmodels.api` submodule and plot the decomposed plot of `userAcceleration.x`. Set `freq=60` in the `seasonal_decompose` function. Your graph should look like the one below.
#
# ![time series decomposition](../images/tsa_decompose.png)

# %%
# Your code here:
import statsmodels.api as sm
import matplotlib as plt

# %%
i = sensor['userAcceleration.x']

# %%
plt.rcParams['axes.labelsize'] =14
plt.rcParams['xtick.labelsize'] =12
plt.rcParams['ytick.labelsize'] =12

i.plot(figsize=(15,6),marker="o",markersize=10,markerfacecolor='red')
# Out:
# <AxesSubplot:xlabel='time'>

# %%
plt.rcParams['figure.figsize'] =11,8
decomposition = sm.tsa.seasonal_decompose(i,model='additive', period = 60)
fig =decomposition.plot()

# %% [markdown]
# Plot the decomposed time series of `rotationRate.x` also with a frequency of 60.

# %% [markdown]
# # Challenge 2 - Modelling the Data
#
# To model our data, we should look at a few assumptions. First, let's plot the `lag_plot` to detect any autocorrelation. Do this for `userAcceleration.x`

# %%
# Your code here:
from pandas.plotting import lag_plot

lag_plot(sensor['userAcceleration.x'])
# Out:
# <AxesSubplot:xlabel='y(t)', ylabel='y(t + 1)'>

# %% [markdown]
# Create a lag plot for `rotationRate.x`

# %%
# Your code here:

lag_plot(sensor['rotationRate.x'])
# Out:
# <AxesSubplot:xlabel='y(t)', ylabel='y(t + 1)'>

# %% [markdown]
# What are your conclusions from both visualizations?

# %%
# Your conclusions here:

# both variables seem to be autocorrelated. userAcceleration.x seems to be more compact to the center.
# rotationRate.x seems more equally spreadout on the line.

# %% [markdown]
# The next step will be to test both variables for stationarity. Perform the Augmented Dickey Fuller test on both variables below.

# %%
# Your code here:
from statsmodels.tsa.stattools import adfuller

adfuller_accel = adfuller(sensor['userAcceleration.x'], autolag=None)
adfuller_rot = adfuller(sensor['rotationRate.x'], autolag=None)

def adfuller_result_printer(adfuller):
    print(f'Prueba estadistica {adfuller[0]}')
    print(f'P-value {adfuller[1]}')
    for k, v in adfuller[4].items():
        print('\t{}:{} Los datos son {} estacionarios con {}% de confianza'.format(k, v, "not" if v < adfuller[0] else "", 100-int(k[:-1])))
    
adfuller_result_printer(adfuller_accel)
print('\n')
adfuller_result_printer(adfuller_rot)
# Out:
# Prueba estadistica -8.160095026835913
# P-value 9.193147705719887e-13
# 	1%:-3.4341465551936534 Los datos son  estacionarios con 99% de confianza
# 	5%:-2.863216966926812 Los datos son  estacionarios con 95% de confianza
# 	10%:-2.567662770090317 Los datos son  estacionarios con 90% de confianza
#
#
# Prueba estadistica -5.269860625086414
# P-value 6.3202303359123905e-06
# 	1%:-3.4341465551936534 Los datos son  estacionarios con 99% de confianza
# 	5%:-2.863216966926812 Los datos son  estacionarios con 95% de confianza
# 	10%:-2.567662770090317 Los datos son  estacionarios con 90% de confianza

# %% [markdown]
# What are your conclusions from this test?

# %%
# Your conclusions here:

# both datasets are stationary, but userAcceleration.x is a little bit more stationary than rotationRate.x

# %% [markdown]
# Finally, we'll create an ARMA model for `userAcceleration.x`. Load the `ARMA` function from `statsmodels`. The order of the model is (2, 1). Split the data to train and test. Use the last 10 observations as the test set and all other observations as the training set.

# %%
# Your code here:
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tools.eval_measures import rmse, meanabs
import itertools

# %%
train, test = sensor['userAcceleration.x'][:-10], sensor['userAcceleration.x'][-10:]

# %%
# fit model
model = ARIMA(train, order=(2, 1, 0), freq = 'S')
model_fit = model.fit()

# make prediction
predictions = model_fit.predict(start=len(train), end=len(train)+len(test)-1, dynamic=False)
# Out:
# c:\users\bravo\appdata\local\programs\python\python38-32\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency S will be used.
#   warnings.warn('No frequency information was'

# %%
pd.DataFrame({'observed':test, 'predicted':predictions})
# Out:
#                      observed  predicted
# 2018-01-01 00:29:01  0.149749   0.187165
# 2018-01-01 00:29:02  0.038461   0.170159
# 2018-01-01 00:29:03 -0.169175   0.148225
# 2018-01-01 00:29:04 -0.300361   0.144826
# 2018-01-01 00:29:05 -0.270174   0.150491
# 2018-01-01 00:29:06 -0.268367   0.153869
# 2018-01-01 00:29:07 -0.102444   0.153415
# 2018-01-01 00:29:08 -0.085590   0.152148
# 2018-01-01 00:29:09 -0.048105   0.151782
# 2018-01-01 00:29:10 -0.065011   0.152041

# %%
print('rmse:', rmse(test, predictions))
print('mape:', meanabs(test, predictions))
# Out:
# rmse: 0.2969797839645293
# mape: 0.26851376715797665

# %%
p = d = q =range(0,2)
pdq=list(itertools.product(p,d,q))
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p,d,q))]

for param in pdq:
    for param_estacionales in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(train,
                                            order=param,
                                            seasonal_order=param_estacionales,
                                            enforce_stationarity=True,
                                            enforce_invertibility=False)
            results = mod.fit()
            print(f'ARIMA {param} x {param_estacionales}12 - AIC:{results.aic}')
        except:
            continue
# Out:
# c:\users\bravo\appdata\local\programs\python\python38-32\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency S will be used.
#   warnings.warn('No frequency information was'
# c:\users\bravo\appdata\local\programs\python\python38-32\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency S will be used.
#   warnings.warn('No frequency information was'
# c:\users\bravo\appdata\local\programs\python\python38-32\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency S will be used.
#   warnings.warn('No frequency information was'
# c:\users\bravo\appdata\local\programs\python\python38-32\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency S will be used.
# ...

# %%
mod = sm.tsa.statespace.SARIMAX(train,
                                            order=(1,0,1),
                                            seasonal_order= (1, 1, 1, 12),
                                            enforce_stationarity= True,
                                            enforce_invertibility= False)
results = mod.fit()
# Out:
# c:\users\bravo\appdata\local\programs\python\python38-32\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency S will be used.
#   warnings.warn('No frequency information was'
# c:\users\bravo\appdata\local\programs\python\python38-32\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency S will be used.
#   warnings.warn('No frequency information was'

# %%
results.plot_diagnostics(figsize=(16,8));

# %%
predictions = results.predict(start=len(train), end=len(train)+len(test)-1, dynamic=False)
pd.DataFrame({'observed':test, 'predicted':predictions})
# Out:
#                      observed  predicted
# 2018-01-01 00:29:01  0.149749   0.157093
# 2018-01-01 00:29:02  0.038461   0.124065
# 2018-01-01 00:29:03 -0.169175   0.102382
# 2018-01-01 00:29:04 -0.300361   0.075981
# 2018-01-01 00:29:05 -0.270174   0.032803
# 2018-01-01 00:29:06 -0.268367   0.029167
# 2018-01-01 00:29:07 -0.102444   0.053374
# 2018-01-01 00:29:08 -0.085590   0.046793
# 2018-01-01 00:29:09 -0.048105   0.030886
# 2018-01-01 00:29:10 -0.065011   0.062592

# %% [markdown]
# To compare our predictions with the observed data, we can compute the RMSE (Root Mean Squared Error) from the submodule `statsmodels.tools.eval_measures`. You can read more about this function [here](https://www.statsmodels.org/dev/generated/statsmodels.tools.eval_measures.rmse.html). Compute the RMSE for the last 10 rows of the data by comparing the observed and predicted data for the `userAcceleration.x` column.

# %%
print('rmse:', rmse(test, predictions))
print('mape:', meanabs(test, predictions))
# Out:
# rmse: 0.21619581675277968
# mape: 0.1836151466031818
