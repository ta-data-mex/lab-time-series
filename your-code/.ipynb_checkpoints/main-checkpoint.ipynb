# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# Import numpy and pandas
import numpy as np
import pandas as pd

# %% [markdown]
# # Challenge 1 - Loading and Evaluating The Data
#
# In this lab, we will look at a dataset of sensor data from a cellular phone. The phone was carried in the subject's pocket for a few minutes while they walked around.
#
# To load the data, run the code below.

# %%
# Run this code:

sensor = pd.read_csv('../sub_1.csv')
sensor.drop(columns=['Unnamed: 0'], inplace=True)

# %% [markdown]
# Examine the data using the `head` function.

# %%
# Your code here:
sensor.head()
# Out:
#    attitude.roll  attitude.pitch  attitude.yaw  gravity.x  gravity.y  \
# 0       1.528132       -0.733896      0.696372   0.741895   0.669768
# 1       1.527992       -0.716987      0.677762   0.753099   0.657116
# 2       1.527765       -0.706999      0.670951   0.759611   0.649555
# 3       1.516768       -0.704678      0.675735   0.760709   0.647788
# 4       1.493941       -0.703918      0.672994   0.760062   0.647210
#
#    gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# 0  -0.031672        0.316738        0.778180        1.082764
# 1  -0.032255        0.842032        0.424446        0.643574
# 2  -0.032707       -0.138143       -0.040741        0.343563
# 3  -0.041140       -0.025005       -1.048717        0.035860
# 4  -0.058530        0.114253       -0.912890        0.047341
#
#    userAcceleration.x  userAcceleration.y  userAcceleration.z
# 0            0.294894           -0.184493            0.377542
# ...

# %% [markdown]
# Check whether there is any missing data. If there is any missing data, remove the rows containing missing data.

# %%
# Your code here:
sensor.isna().sum()
# vemos que no hay nan values, por tanto no necesario remover data
# Out:
# attitude.roll         0
# attitude.pitch        0
# attitude.yaw          0
# gravity.x             0
# gravity.y             0
# gravity.z             0
# rotationRate.x        0
# rotationRate.y        0
# rotationRate.z        0
# userAcceleration.x    0
# userAcceleration.y    0
# userAcceleration.z    0
# dtype: int64

# %% [markdown]
# How many rows and columns are in our data?

# %%
# Your code here:
sensor.shape
# existen 1751 filas
# existn 12 columnas
# Out:
# (1751, 12)

# %% [markdown]
# To perform time series analysis on the data, we must change the index from a range index to a time series index. In the cell below, create a time series index using the `pd.date_range` function. Create a time series index starting at 1/1/2018 00:00:00 and ending at 1/1/2018 00:29:10. The number of periods is equal to the number of rows in `sensor`. The frequency should be set to `infer`.

# %%
# Your code here:
date_info = pd.date_range(start='1/1/2018 00:00:00', end='1/1/2018 00:29:10', periods=1751)
#date_info = pd.date_range(start='1/1/2018 00:00:00', end='1/1/2018 00:29:10', periods=1751, freq='infer')
date_info
# Out:
# DatetimeIndex(['2018-01-01 00:00:00', '2018-01-01 00:00:01',
#                '2018-01-01 00:00:02', '2018-01-01 00:00:03',
#                '2018-01-01 00:00:04', '2018-01-01 00:00:05',
#                '2018-01-01 00:00:06', '2018-01-01 00:00:07',
#                '2018-01-01 00:00:08', '2018-01-01 00:00:09',
#                ...
#                '2018-01-01 00:29:01', '2018-01-01 00:29:02',
#                '2018-01-01 00:29:03', '2018-01-01 00:29:04',
#                '2018-01-01 00:29:05', '2018-01-01 00:29:06',
#                '2018-01-01 00:29:07', '2018-01-01 00:29:08',
#                '2018-01-01 00:29:09', '2018-01-01 00:29:10'],
#               dtype='datetime64[ns]', length=1751, freq=None)

# %% [markdown]
# Assign the time series index to the dataframe's index.

# %%
# Your code here:
sensor = sensor.set_index(date_info)
sensor.head()
# Out:
#                      attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 2018-01-01 00:00:00       1.528132       -0.733896      0.696372   0.741895
# 2018-01-01 00:00:01       1.527992       -0.716987      0.677762   0.753099
# 2018-01-01 00:00:02       1.527765       -0.706999      0.670951   0.759611
# 2018-01-01 00:00:03       1.516768       -0.704678      0.675735   0.760709
# 2018-01-01 00:00:04       1.493941       -0.703918      0.672994   0.760062
#
#                      gravity.y  gravity.z  rotationRate.x  rotationRate.y  \
# 2018-01-01 00:00:00   0.669768  -0.031672        0.316738        0.778180
# 2018-01-01 00:00:01   0.657116  -0.032255        0.842032        0.424446
# 2018-01-01 00:00:02   0.649555  -0.032707       -0.138143       -0.040741
# 2018-01-01 00:00:03   0.647788  -0.041140       -0.025005       -1.048717
# 2018-01-01 00:00:04   0.647210  -0.058530        0.114253       -0.912890
#
# ...

# %% [markdown]
# Our next step is to decompose the time series and evaluate the patterns in the data. Load the `statsmodels.api` submodule and plot the decomposed plot of `userAcceleration.x`. Set `freq=60` in the `seasonal_decompose` function. Your graph should look like the one below.
#
# ![time series decomposition](../images/tsa_decompose.png)

# %%
# Your code here:
import statsmodels.api as sm
from pylab import rcParams
import matplotlib.pyplot as plt

# %%
acceleration_x = pd.DataFrame(sensor['userAcceleration.x'])
acceleration_x
# Out:
#                      userAcceleration.x
# 2018-01-01 00:00:00            0.294894
# 2018-01-01 00:00:01            0.219405
# 2018-01-01 00:00:02            0.010714
# 2018-01-01 00:00:03           -0.008389
# 2018-01-01 00:00:04            0.199441
# ...                                 ...
# 2018-01-01 00:29:06           -0.268367
# 2018-01-01 00:29:07           -0.102444
# 2018-01-01 00:29:08           -0.085590
# 2018-01-01 00:29:09           -0.048105
# 2018-01-01 00:29:10           -0.065011
#
# [1751 rows x 1 columns]

# %%
rcParams['figure.figsize'] = 20, 12
decomposition = sm.tsa.seasonal_decompose(acceleration_x, model='additive',period=60)
decomposition.plot()
plt.show()

# %% [markdown]
# Plot the decomposed time series of `rotationRate.x` also with a frequency of 60.

# %%
rotation_x = pd.DataFrame(sensor['rotationRate.x'])
rotation_x
# Out:
#                      rotationRate.x
# 2018-01-01 00:00:00        0.316738
# 2018-01-01 00:00:01        0.842032
# 2018-01-01 00:00:02       -0.138143
# 2018-01-01 00:00:03       -0.025005
# 2018-01-01 00:00:04        0.114253
# ...                             ...
# 2018-01-01 00:29:06       -0.123211
# 2018-01-01 00:29:07       -0.057641
# 2018-01-01 00:29:08        0.343238
# 2018-01-01 00:29:09        0.470144
# 2018-01-01 00:29:10        0.291873
#
# [1751 rows x 1 columns]

# %%
rcParams['figure.figsize'] = 20, 12
decomposition = sm.tsa.seasonal_decompose(rotation_x, model='additive',period=60)
decomposition.plot()
plt.show()

# %% [markdown]
# # Challenge 2 - Modelling the Data
#
# To model our data, we should look at a few assumptions. First, let's plot the `lag_plot` to detect any autocorrelation. Do this for `userAcceleration.x`

# %%
from pandas.plotting import lag_plot

# %%
# Your code here:
lag_plot(sensor['userAcceleration.x'])

# %% [markdown]
# Create a lag plot for `rotationRate.x`

# %%
# Your code here:
lag_plot(sensor['rotationRate.x'])

# %% [markdown]
# What are your conclusions from both visualizations?

# %%
# Your conclusions here:
# Al notar que ambos datos no son aleatorios, vemos que tienn correlación
# con ellos mismos
# Por tanto se podría decir que al acelerar o rotar lo hacen de manera uniforme

# %% [markdown]
# The next step will be to test both variables for stationarity. Perform the Augmented Dickey Fuller test on both variables below.

# %%
# Your code here:
from statsmodels.tsa.stattools import adfuller

# %%
acceleration_fuller = adfuller(sensor['userAcceleration.x'], autolag = None)

# %%
print(f'Prueba estadistica {acceleration_fuller[0]}')
print(f'P.value={acceleration_fuller[1]}')
print(f'Valores criticos:')
for k, v in acceleration_fuller[4].items():
    print('\t{}:{} Los datos {} estacionarios con {}% de confianza'.format(k,v, "not" if v < acceleration_fuller[0] else "", 100-int(k[:-1])))
# Out:
# Prueba estadistica -8.160095026835915
# P.value=9.19314770571972e-13
# Valores criticos:
# 	1%:-3.4341465551936534 Los datos  estacionarios con 99% de confianza
# 	5%:-2.863216966926812 Los datos  estacionarios con 95% de confianza
# 	10%:-2.567662770090317 Los datos  estacionarios con 90% de confianza

# %%
rotation_fuller = adfuller(sensor['rotationRate.x'], autolag = None)

# %%
print(f'Prueba estadistica {rotation_fuller[0]}')
print(f'P.value={rotation_fuller[1]}')
print(f'Valores criticos:')
for k, v in rotation_fuller[4].items():
    print('\t{}:{} Los datos {} estacionarios con {}% de confianza'.format(k,v, "not" if v < rotation_fuller[0] else "", 100-int(k[:-1])))
# Out:
# Prueba estadistica -5.269860625086435
# P.value=6.320230335911768e-06
# Valores criticos:
# 	1%:-3.4341465551936534 Los datos  estacionarios con 99% de confianza
# 	5%:-2.863216966926812 Los datos  estacionarios con 95% de confianza
# 	10%:-2.567662770090317 Los datos  estacionarios con 90% de confianza

# %% [markdown]
# What are your conclusions from this test?

# %%
# Your conclusions here:
# Al ver que el valor de p-value es muy pequeño. Descurbrimos que los datos son 
# estacionarios

# %% [markdown]
# Finally, we'll create an ARMA model for `userAcceleration.x`. Load the `ARMA` function from `statsmodels`. The order of the model is (2, 1). Split the data to train and test. Use the last 10 observations as the test set and all other observations as the training set.

# %%
# Your code here:
from statsmodels.tsa.arima_model import ARMA

# %%
train , test = sensor["userAcceleration.x"][:-10] , sensor["userAcceleration.x"][-10:]
modelo=ARMA(train,order=(2,1)).fit()
print(modelo.summary())
# Out:
#                               ARMA Model Results
# ...
# Dep. Variable:     userAcceleration.x   No. Observations:                 1741
# Model:                     ARMA(2, 1)   Log Likelihood                 373.401
# Method:                       css-mle   S.D. of innovations              0.195
# Date:                Sun, 05 Jul 2020   AIC                           -736.803
# Time:                        18:21:18   BIC                           -709.492
# Sample:                             0   HQIC                          -726.704
#
# ...
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        0.0637      0.014      4.503      0.000       0.036       0.091
# ar.L1.userAcceleration.x     0.9882      0.044     22.639      0.000       0.903       1.074
# ...

# %% [markdown]
# To compare our predictions with the observed data, we can compute the RMSE (Root Mean Squared Error) from the submodule `statsmodels.tools.eval_measures`. You can read more about this function [here](https://www.statsmodels.org/dev/generated/statsmodels.tools.eval_measures.rmse.html). Compute the RMSE for the last 10 rows of the data by comparing the observed and predicted data for the `userAcceleration.x` column.

# %%
prediccion=modelo.predict(start=len(train),end=len(train)+9)
prediccion
# Out:
# 1741    0.173149
# 1742    0.142896
# 1743    0.100522
# 1744    0.070106
# 1745    0.056099
# 1746    0.053778
# 1747    0.056790
# 1748    0.060646
# 1749    0.063316
# 1750    0.064493
# dtype: float64

# %%
error=pd.concat([test,prediccion],axis=1)

# %%
error.rename(columns={0:'prediction'}, inplace=True)
error
# Out:
#       userAcceleration.x  prediction
# 1741            0.149749    0.173149
# 1742            0.038461    0.142896
# 1743           -0.169175    0.100522
# 1744           -0.300361    0.070106
# 1745           -0.270174    0.056099
# 1746           -0.268367    0.053778
# 1747           -0.102444    0.056790
# 1748           -0.085590    0.060646
# 1749           -0.048105    0.063316
# 1750           -0.065011    0.064493

# %%
error.columns=["Test","Predicción"]
error
# Out:
#           Test  Predicción
# 1741  0.149749    0.173149
# 1742  0.038461    0.142896
# 1743 -0.169175    0.100522
# 1744 -0.300361    0.070106
# 1745 -0.270174    0.056099
# 1746 -0.268367    0.053778
# 1747 -0.102444    0.056790
# 1748 -0.085590    0.060646
# 1749 -0.048105    0.063316
# 1750 -0.065011    0.064493

# %%
import statsmodels.tools.eval_measures as smrsme
smrsme.rmse(error['Test'],error['Predicción'])
# este es el error medio cuadrático
# Out:
# 0.22529863492582616

# %%
error.plot()
