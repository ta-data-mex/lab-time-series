# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# Import numpy and pandas
import pandas as pd
import numpy as np

# %% [markdown]
# # Challenge 1 - Loading and Evaluating The Data
#
# In this lab, we will look at a dataset of sensor data from a cellular phone. The phone was carried in the subject's pocket for a few minutes while they walked around.
#
# To load the data, run the code below.

# %%
# Run this code:

sensor = pd.read_csv('../sub_1.csv')
sensor.drop(columns=['Unnamed: 0'], inplace=True)

# %% [markdown]
# Examine the data using the `head` function.

# %%
# Your code here:
sensor.head()
# Out:
#    attitude.roll  attitude.pitch  attitude.yaw  gravity.x  gravity.y  \
# 0       1.528132       -0.733896      0.696372   0.741895   0.669768
# 1       1.527992       -0.716987      0.677762   0.753099   0.657116
# 2       1.527765       -0.706999      0.670951   0.759611   0.649555
# 3       1.516768       -0.704678      0.675735   0.760709   0.647788
# 4       1.493941       -0.703918      0.672994   0.760062   0.647210
#
#    gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# 0  -0.031672        0.316738        0.778180        1.082764
# 1  -0.032255        0.842032        0.424446        0.643574
# 2  -0.032707       -0.138143       -0.040741        0.343563
# 3  -0.041140       -0.025005       -1.048717        0.035860
# 4  -0.058530        0.114253       -0.912890        0.047341
#
#    userAcceleration.x  userAcceleration.y  userAcceleration.z
# 0            0.294894           -0.184493            0.377542
# ...

# %% [markdown]
# Check whether there is any missing data. If there is any missing data, remove the rows containing missing data.

# %%
# Your code here:
sensor.isnull().sum()
# Out:
# attitude.roll         0
# attitude.pitch        0
# attitude.yaw          0
# gravity.x             0
# gravity.y             0
# gravity.z             0
# rotationRate.x        0
# rotationRate.y        0
# rotationRate.z        0
# userAcceleration.x    0
# userAcceleration.y    0
# userAcceleration.z    0
# dtype: int64

# %% [markdown]
# How many rows and columns are in our data?

# %%
# Your code here:
sensor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1751 entries, 0 to 1750
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   attitude.roll       1751 non-null   float64
#  1   attitude.pitch      1751 non-null   float64
#  2   attitude.yaw        1751 non-null   float64
#  3   gravity.x           1751 non-null   float64
#  4   gravity.y           1751 non-null   float64
#  5   gravity.z           1751 non-null   float64
#  6   rotationRate.x      1751 non-null   float64
#  7   rotationRate.y      1751 non-null   float64
#  8   rotationRate.z      1751 non-null   float64
#  9   userAcceleration.x  1751 non-null   float64
#  10  userAcceleration.y  1751 non-null   float64
#  11  userAcceleration.z  1751 non-null   float64
# dtypes: float64(12)
# memory usage: 164.3 KB

# %% [markdown]
# To perform time series analysis on the data, we must change the index from a range index to a time series index. In the cell below, create a time series index using the `pd.date_range` function. Create a time series index starting at 1/1/2018 00:00:00 and ending at 1/1/2018 00:29:10. The number of periods is equal to the number of rows in `sensor`. The frequency should be set to `infer`.

# %%
# Your code here:
df_time = pd.date_range(start='1/1/2018 00:00:00', 
                        end='1/1/2018 00:29:10', 
                        freq='s')

df_time
# Out:
# DatetimeIndex(['2018-01-01 00:00:00', '2018-01-01 00:00:01',
#                '2018-01-01 00:00:02', '2018-01-01 00:00:03',
#                '2018-01-01 00:00:04', '2018-01-01 00:00:05',
#                '2018-01-01 00:00:06', '2018-01-01 00:00:07',
#                '2018-01-01 00:00:08', '2018-01-01 00:00:09',
#                ...
#                '2018-01-01 00:29:01', '2018-01-01 00:29:02',
#                '2018-01-01 00:29:03', '2018-01-01 00:29:04',
#                '2018-01-01 00:29:05', '2018-01-01 00:29:06',
#                '2018-01-01 00:29:07', '2018-01-01 00:29:08',
#                '2018-01-01 00:29:09', '2018-01-01 00:29:10'],
#               dtype='datetime64[ns]', length=1751, freq='S')

# %% [markdown]
# Assign the time series index to the dataframe's index.

# %%
# Your code here:

sensor = sensor.set_index(df_time)
sensor
# Out:
#                      attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 2018-01-01 00:00:00       1.528132       -0.733896      0.696372   0.741895
# 2018-01-01 00:00:01       1.527992       -0.716987      0.677762   0.753099
# 2018-01-01 00:00:02       1.527765       -0.706999      0.670951   0.759611
# 2018-01-01 00:00:03       1.516768       -0.704678      0.675735   0.760709
# 2018-01-01 00:00:04       1.493941       -0.703918      0.672994   0.760062
# ...                            ...             ...           ...        ...
# 2018-01-01 00:29:06       1.797120       -0.562324      2.445889   0.824443
# 2018-01-01 00:29:07       1.814297       -0.569719      2.449655   0.817212
# 2018-01-01 00:29:08       1.830821       -0.578367      2.447967   0.809207
# 2018-01-01 00:29:09       1.849557       -0.586962      2.439458   0.800485
# 2018-01-01 00:29:10       1.869375       -0.596783      2.433775   0.790551
#
# ...

# %% [markdown]
# Our next step is to decompose the time series and evaluate the patterns in the data. Load the `statsmodels.api` submodule and plot the decomposed plot of `userAcceleration.x`. Set `freq=60` in the `seasonal_decompose` function. Your graph should look like the one below.
#
# ![time series decomposition](../images/tsa_decompose.png)

# %%
# Your code here:
import statsmodels.api as sm
from pylab import rcParams
from statsmodels.graphics import tsaplots
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.statespace.sarimax import SARIMAX
import matplotlib.pyplot as plt

# %%
rcParams['figure.figsize'] = 18, 8

decomposition = sm.tsa.seasonal_decompose(sensor['userAcceleration.x'], period=60)
fig = decomposition.plot()
plt.show();

# %%
rcParams['figure.figsize'] = 18, 8

decomposition = sm.tsa.seasonal_decompose(sensor['rotationRate.x'], period=60)
fig = decomposition.plot()
plt.show();

# %% [markdown]
# Plot the decomposed time series of `rotationRate.x` also with a frequency of 60.

# %% [markdown]
# # Challenge 2 - Modelling the Data
#
# To model our data, we should look at a few assumptions. First, let's plot the `lag_plot` to detect any autocorrelation. Do this for `userAcceleration.x`

# %%
tsaplots.plot_acf(sensor['userAcceleration.x'].values.squeeze(), lags=40)
plt.xlabel('Lags')
plt.ylabel('Coeficiente de autocorrelación')
plt.show()

# %%
# Your code here:
plt.scatter(sensor['userAcceleration.x'], sensor['userAcceleration.x'].shift(1));

# %% [markdown]
# Create a lag plot for `rotationRate.x`

# %%
tsaplots.plot_acf(sensor['rotationRate.x'].values.squeeze(), lags=40)
plt.xlabel('Lags')
plt.ylabel('Coeficiente de autocorrelación')
plt.show()

# %%
# Your code here:
plt.scatter(sensor['rotationRate.x'], sensor['rotationRate.x'].shift(1));

# %% [markdown]
# What are your conclusions from both visualizations?

# %%
# Your conclusions here:
"""En la grafica sobre el userAcceleration.x muestra autocorrelacion en las primeras observaciones del periodo, es decir,
que su nivel de correlacion es mas ligera con respecto a la grafica de rotationRate.x, la cual muestra una correlacion muy alta,
en diferentes momentos de las observaciones"""

# %% [markdown]
# The next step will be to test both variables for stationarity. Perform the Augmented Dickey Fuller test on both variables below.

# %%
H0 = Nuestros datos no son estacionarios

H1 = Nuestros datos sí son estacionarios

# %%
# Your code here:
class Stationary:
    def __init__(self, significance=0.05):
        self.significance_level = significance
        self.pvalue = None
        self.is_stationary = None
    
    def ADF(self, values):
        result = adfuller(values, autolag='AIC')
        
        format_results = pd.Series(result[:4], 
                                index=['Statistic', 'P-value',
                                      'Num of Lags', 'Observations'])
        
        for k,v in result[4].items():
            format_results[f'Critical Value {k}'] = v
        
        return format_results

# %%
adf_test = Stationary()
print(adf_test)
adf_test.ADF(sensor['userAcceleration.x'].values).round(5)
# Out:
# ...
# Statistic              -17.95799
# P-value                  0.00000
# Num of Lags              4.00000
# Observations          1746.00000
# Critical Value 1%       -3.43410
# Critical Value 5%       -2.86320
# Critical Value 10%      -2.56765
# dtype: float64

# %%
adf_test = Stationary()
print(adf_test)
adf_test.ADF(sensor['rotationRate.x'].values).round(5)
# Out:
# ...
# Statistic               -5.26986
# P-value                  0.00001
# Num of Lags             25.00000
# Observations          1725.00000
# Critical Value 1%       -3.43415
# Critical Value 5%       -2.86322
# Critical Value 10%      -2.56766
# dtype: float64

# %% [markdown]
# What are your conclusions from this test?

# %%
# Your conclusions here:
"""Se rechaza la hipotesis nula a de que nuestros datos no son estacionarios. A un 95% de confianza se concluye que las series 
temporales de las dos variables son estacionarias, a partir de los valores del p-value menores al 0.05"""

# %% [markdown]
# Finally, we'll create an ARMA model for `userAcceleration.x`. Load the `ARMA` function from `statsmodels`. The order of the model is (2, 1). Split the data to train and test. Use the last 10 observations as the test set and all other observations as the training set.

# %%
from statsmodels.tsa.arima_model import ARMA

# %%
test = sensor['userAcceleration.x'][-10:]
train = sensor['userAcceleration.x'][:-10]

# %%
# Your code here:
model_arma = SARIMAX(train, 
                    order=(2,0,1), 
                    enforce_stationarity=False)

results = model_arma.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:     userAcceleration.x   No. Observations:                 1741
# Model:               SARIMAX(2, 0, 1)   Log Likelihood                 363.376
# Date:                Tue, 10 May 2022   AIC                           -718.752
# Time:                        23:30:01   BIC                           -696.907
# Sample:                    01-01-2018   HQIC                          -710.674
#                          - 01-01-2018
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9821      0.036     27.289      0.000       0.912       1.053
# ar.L2         -0.3615      0.033    -10.874      0.000      -0.427      -0.296
# ma.L1          0.1988      0.039      5.040      0.000       0.122       0.276
# ...

# %%
results.plot_diagnostics()
plt.show()

# %%
sensor.reset_index().iloc[1741, 0]
# Out:
# Timestamp('2018-01-01 00:29:01')

# %%
start = sensor.reset_index().iloc[1741, 0]
end = sensor.reset_index().iloc[-1, 0]

start, end
# Out:
# (Timestamp('2018-01-01 00:29:01'), Timestamp('2018-01-01 00:29:10'))

# %%
test
# Out:
# 2018-01-01 00:29:01    0.149749
# 2018-01-01 00:29:02    0.038461
# 2018-01-01 00:29:03   -0.169175
# 2018-01-01 00:29:04   -0.300361
# 2018-01-01 00:29:05   -0.270174
# 2018-01-01 00:29:06   -0.268367
# 2018-01-01 00:29:07   -0.102444
# 2018-01-01 00:29:08   -0.085590
# 2018-01-01 00:29:09   -0.048105
# 2018-01-01 00:29:10   -0.065011
# Freq: S, Name: userAcceleration.x, dtype: float64

# %%
pred = results.predict(start=start, end=end)
pred_ci = results.get_prediction(start=start, end=end).conf_int()

sensor_pred = pd.DataFrame(pred, index=sensor.iloc[1741:].index, columns=['userAcceleration.x'])

# %%
pred
# Out:
# 2018-01-01 00:29:01    0.153927
# 2018-01-01 00:29:02    0.100482
# 2018-01-01 00:29:03    0.043037
# 2018-01-01 00:29:04    0.005942
# 2018-01-01 00:29:05   -0.009722
# 2018-01-01 00:29:06   -0.011696
# 2018-01-01 00:29:07   -0.007971
# 2018-01-01 00:29:08   -0.003601
# 2018-01-01 00:29:09   -0.000655
# 2018-01-01 00:29:10    0.000659
# Freq: S, Name: predicted_mean, dtype: float64

# %%
sensor_pred = pd.DataFrame(pred)

# %%
sensor_pred
# Out:
#                      predicted_mean
# 2018-01-01 00:29:01        0.153927
# 2018-01-01 00:29:02        0.100482
# 2018-01-01 00:29:03        0.043037
# 2018-01-01 00:29:04        0.005942
# 2018-01-01 00:29:05       -0.009722
# 2018-01-01 00:29:06       -0.011696
# 2018-01-01 00:29:07       -0.007971
# 2018-01-01 00:29:08       -0.003601
# 2018-01-01 00:29:09       -0.000655
# 2018-01-01 00:29:10        0.000659

# %%
pred_ci.head()
# Out:
#                      lower userAcceleration.x  upper userAcceleration.x
# 2018-01-01 00:29:01                 -0.230882                  0.538737
# 2018-01-01 00:29:02                 -0.494983                  0.695948
# 2018-01-01 00:29:03                 -0.626986                  0.713061
# 2018-01-01 00:29:04                 -0.678023                  0.689908
# 2018-01-01 00:29:05                 -0.694104                  0.674661

# %%
rcParams['figure.figsize'] = 25, 8

ax = sensor['userAcceleration.x'].plot(label='observado')
sensor_pred['predicted_mean'].plot(c='r', alpha=0.3) 
ax.fill_between(pred_ci.index, 
                pred_ci.iloc[:, 0], 
                pred_ci.iloc[:, 1], 
                color='r', alpha=0.2)
ax.set_xlabel('Tiempo')
ax.set_ylabel('Medida')
plt.legend()
plt.show();

# %% [markdown]
# To compare our predictions with the observed data, we can compute the RMSE (Root Mean Squared Error) from the submodule `statsmodels.tools.eval_measures`. You can read more about this function [here](https://www.statsmodels.org/dev/generated/statsmodels.tools.eval_measures.rmse.html). Compute the RMSE for the last 10 rows of the data by comparing the observed and predicted data for the `userAcceleration.x` column.

# %%
# Your code here:

from statsmodels.tools.eval_measures import rmse

# %%
y_test = test

rmse(y_test, pred)
# Out:
# 0.1728140460982883
