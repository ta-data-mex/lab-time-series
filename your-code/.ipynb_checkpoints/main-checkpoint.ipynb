# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# Import numpy and pandas
import numpy as numpybb
import pandas as panditasbb

# %% [markdown]
# # Challenge 1 - Loading and Evaluating The Data
#
# In this lab, we will look at a dataset of sensor data from a cellular phone. The phone was carried in the subject's pocket for a few minutes while they walked around.
#
# To load the data, run the code below.

# %%
# Run this code:

sensor = panditasbb.read_csv('../sub_1.csv')
sensor.drop(columns=['Unnamed: 0'], inplace=True)

# %% [markdown]
# Examine the data using the `head` function.

# %%
# Your code here:
sensor.head()
# Out:
#    attitude.roll  attitude.pitch  attitude.yaw  gravity.x  gravity.y  \
# 0       1.528132       -0.733896      0.696372   0.741895   0.669768
# 1       1.527992       -0.716987      0.677762   0.753099   0.657116
# 2       1.527765       -0.706999      0.670951   0.759611   0.649555
# 3       1.516768       -0.704678      0.675735   0.760709   0.647788
# 4       1.493941       -0.703918      0.672994   0.760062   0.647210
#
#    gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# 0  -0.031672        0.316738        0.778180        1.082764
# 1  -0.032255        0.842032        0.424446        0.643574
# 2  -0.032707       -0.138143       -0.040741        0.343563
# 3  -0.041140       -0.025005       -1.048717        0.035860
# 4  -0.058530        0.114253       -0.912890        0.047341
#
#    userAcceleration.x  userAcceleration.y  userAcceleration.z
# 0            0.294894           -0.184493            0.377542
# ...

# %% [markdown]
# Check whether there is any missing data. If there is any missing data, remove the rows containing missing data.

# %%
# Your code here:
sensor.isnull().sum()
# Validamos que no hay null en ningun columna
# Out:
# attitude.roll         0
# attitude.pitch        0
# attitude.yaw          0
# gravity.x             0
# gravity.y             0
# gravity.z             0
# rotationRate.x        0
# rotationRate.y        0
# rotationRate.z        0
# userAcceleration.x    0
# userAcceleration.y    0
# userAcceleration.z    0
# dtype: int64

# %% [markdown]
# How many rows and columns are in our data?

# %%
# Your code here:
sensor.shape
# Out:
# (1751, 12)

# %% [markdown]
# To perform time series analysis on the data, we must change the index from a range index to a time series index. In the cell below, create a time series index using the `pd.date_range` function. Create a time series index starting at 1/1/2018 00:00:00 and ending at 1/1/2018 00:29:10. The number of periods is equal to the number of rows in `sensor`. The frequency should be set to `infer`.

# %%
# Your code here:
# per1 = pd.date_range(start ='1-1-2018', end ='1-05-2018', freq ='5H')

# Crear DataSeries tipo DateTime con el rango definido por el problema
time = panditasbb.date_range(start='1-1-2018 00:00:00', end='1-1-2018 00:29:10', freq='S')
time
# Out:
# DatetimeIndex(['2018-01-01 00:00:00', '2018-01-01 00:00:01',
#                '2018-01-01 00:00:02', '2018-01-01 00:00:03',
#                '2018-01-01 00:00:04', '2018-01-01 00:00:05',
#                '2018-01-01 00:00:06', '2018-01-01 00:00:07',
#                '2018-01-01 00:00:08', '2018-01-01 00:00:09',
#                ...
#                '2018-01-01 00:29:01', '2018-01-01 00:29:02',
#                '2018-01-01 00:29:03', '2018-01-01 00:29:04',
#                '2018-01-01 00:29:05', '2018-01-01 00:29:06',
#                '2018-01-01 00:29:07', '2018-01-01 00:29:08',
#                '2018-01-01 00:29:09', '2018-01-01 00:29:10'],
#               dtype='datetime64[ns]', length=1751, freq='S')

# %% [markdown]
# Assign the time series index to the dataframe's index.

# %%
# Your code here:
#ratings['Tom'] = panditasbb.Series(tom)

# Agregar el DataSeries anterior al DataFrame que vamos a estar utilizando
sensor['Time'] = panditasbb.Series(time)
sensor = sensor.set_index('Time')
sensor
# Out:
#                      attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# Time
# 2018-01-01 00:00:00       1.528132       -0.733896      0.696372   0.741895
# 2018-01-01 00:00:01       1.527992       -0.716987      0.677762   0.753099
# 2018-01-01 00:00:02       1.527765       -0.706999      0.670951   0.759611
# 2018-01-01 00:00:03       1.516768       -0.704678      0.675735   0.760709
# 2018-01-01 00:00:04       1.493941       -0.703918      0.672994   0.760062
# ...                            ...             ...           ...        ...
# 2018-01-01 00:29:06       1.797120       -0.562324      2.445889   0.824443
# 2018-01-01 00:29:07       1.814297       -0.569719      2.449655   0.817212
# 2018-01-01 00:29:08       1.830821       -0.578367      2.447967   0.809207
# 2018-01-01 00:29:09       1.849557       -0.586962      2.439458   0.800485
# 2018-01-01 00:29:10       1.869375       -0.596783      2.433775   0.790551
#
# ...

# %% [markdown]
# Our next step is to decompose the time series and evaluate the patterns in the data. Load the `statsmodels.api` submodule and plot the decomposed plot of `userAcceleration.x`. Set `freq=60` in the `seasonal_decompose` function. Your graph should look like the one below.
#
# ![time series decomposition](../images/tsa_decompose.png)

# %%
y = sensor['userAcceleration.x'].resample('S').mean()

# Obtenemos un promedio por segundo de la columna Acceleration, no era necesario porque la frecuencia coincide con el sampling que tenemos

# %%
# Your code here:
import statsmodels.api as sm
from pylab import rcParams
import matplotlib.pyplot as plt

rcParams['figure.figsize'] = 18, 8
decomposition = sm.tsa.seasonal_decompose(y, model='additive', period=60)
fig = decomposition.plot()
plt.show()

# Hacemos la descomposición de la data para mostrar sus parámetros (Observed, Trend, Seasonal, Residual), luego lo ploteamos

# %% [markdown]
# Plot the decomposed time series of `rotationRate.x` also with a frequency of 60.

# %%
rotationRate_x = sensor['rotationRate.x'].resample('S').mean()
rcParams['figure.figsize'] = 18, 8
decomposition = sm.tsa.seasonal_decompose(rotationRate_x, model='additive', freq=60)
fig = decomposition.plot()
plt.show()

# Lo mismo que lo anterior pero para otra columna
# Out:
# /Users/ponejo/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: the 'freq'' keyword is deprecated, use 'period' instead
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# # Challenge 2 - Modelling the Data
#
# To model our data, we should look at a few assumptions. First, let's plot the `lag_plot` to detect any autocorrelation. Do this for `userAcceleration.x`

# %%
# Your code here:
from pandas.plotting import lag_plot
lag_plot(sensor['userAcceleration.x']);

# Hacemos uso de lag_plot para conocer la autocorrelación

# %% [markdown]
# Create a lag plot for `rotationRate.x`

# %%
# Your code here:
lag_plot(sensor['rotationRate.x']);
# x2

# %% [markdown]
# What are your conclusions from both visualizations?

# %% [markdown]
# # Your conclusions here:
# El primer plot tiene mayor dispersión, por lo tanto la rotación tiene mayor correlación, es decir, hay menos cambios abruptos de un segundo a otro
# Por lo tanto, se puede usar la rotación para modelar predicciones

# %% [markdown]
# The next step will be to test both variables for stationarity. Perform the Augmented Dickey Fuller test on both variables below.

# %%
# Your code here:
from statsmodels.tsa.stattools import adfuller

print("Los datos son estacionarios?")
dftest = adfuller(sensor['userAcceleration.x'], autolag=None)  # Hacemos la prueba de Fuller (adfuller)
# LAG es la ventana de tiempo que vas moviendo para comparar conforme pasas en el tiempo
print(f'Prueba estadística {dftest[0]}') #Imprimimos el vlaor de la prueba estadística de Fuller
print(f'P-value={dftest[1]}')   # Imprimimos el p-value de la prueba de Fuller
print(f'Valores críticos:')
for k, v in dftest[4].items():
    print('\t{}:{} Los datos son {} estacionarios con {}% de confianza'.format(k, v, "not" if v < dftest[0] else "", 100-int(k[:-1])))
# Out:
# Los datos son estacionarios?
# Prueba estadística -8.160095026835933
# P-value=9.19314770571882e-13
# Valores críticos:
# 	1%:-3.4341465551936534 Los datos son  estacionarios con 99% de confianza
# 	5%:-2.863216966926812 Los datos son  estacionarios con 95% de confianza
# 	10%:-2.567662770090317 Los datos son  estacionarios con 90% de confianza

# %%
print("Los datos son estacionarios?")
dftest = adfuller(sensor['rotationRate.x'], autolag=None)
# LAG es la ventana de tiempo que vas moviendo para comparar conforme pasas en el tiempo
print(f'Prueba estadística {dftest[0]}')
print(f'P-value={dftest[1]}')
print(f'Valores críticos:')
for k, v in dftest[4].items():
    print('\t{}:{} Los datos son {} estacionarios con {}% de confianza'.format(k, v, "not" if v < dftest[0] else "", 100-int(k[:-1])))  
    
    
# x2
# Out:
# Los datos son estacionarios?
# Prueba estadística -5.26986062508642
# P-value=6.320230335912249e-06
# Valores críticos:
# 	1%:-3.4341465551936534 Los datos son  estacionarios con 99% de confianza
# 	5%:-2.863216966926812 Los datos son  estacionarios con 95% de confianza
# 	10%:-2.567662770090317 Los datos son  estacionarios con 90% de confianza

# %% [markdown]
# What are your conclusions from this test?

# %% [markdown]
# # Your conclusions here:
# Dado que nuestra hipótesis nula, por default, es que la serie es no estacionaria, y tanto la prueba estadística como el p-value, nos indican que debemos rechazar la H0:
# La aceleración y la rotación son estacionarias, es decir, no tienen una estructura dependiente del tiempo.

# %% [markdown]
# Finally, we'll create an ARMA model for `userAcceleration.x`. Load the `ARMA` function from `statsmodels`. The order of the model is (2, 1). Split the data to train and test. Use the last 10 observations as the test set and all other observations as the training set.

# %%
# Your code here:
from statsmodels.tsa.arima_model import ARMA
train, test = sensor['userAcceleration.x'][:-10], sensor['userAcceleration.x'][-10:]

# fit model
model = ARMA(sensor['userAcceleration.x'], order=(2, 1))
model_fit = model.fit(disp=False)

# make prediction
predictions = model_fit.predict(start=len(train), end=len(train)+len(test)-1, dynamic=False)

# Compare predictions vs observed
# pd.DataFrame({'observed':test, 'predicted':predictions})

compare = panditasbb.DataFrame({'Observa-Dittos':test, 'Predeci-Dittos':predictions})
compare
# Out:
# /Users/ponejo/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency S will be used.
#   % freq, ValueWarning)
#                      Observa-Dittos  Predeci-Dittos
# 2018-01-01 00:29:01        0.149749        0.172776
# 2018-01-01 00:29:02        0.038461        0.115159
# 2018-01-01 00:29:03       -0.169175       -0.008270
# 2018-01-01 00:29:04       -0.300361       -0.186762
# 2018-01-01 00:29:05       -0.270174       -0.229210
# 2018-01-01 00:29:06       -0.268367       -0.136440
# 2018-01-01 00:29:07       -0.102444       -0.162658
# 2018-01-01 00:29:08       -0.085590        0.035719
# 2018-01-01 00:29:09       -0.048105       -0.043530
# 2018-01-01 00:29:10       -0.065011        0.008415

# %% [markdown]
# To compare our predictions with the observed data, we can compute the RMSE (Root Mean Squared Error) from the submodule `statsmodels.tools.eval_measures`. You can read more about this function [here](https://www.statsmodels.org/dev/generated/statsmodels.tools.eval_measures.rmse.html). Compute the RMSE for the last 10 rows of the data by comparing the observed and predicted data for the `userAcceleration.x` column.

# %%
# Your code here:
from statsmodels.tools.eval_measures import rmse 
# statsmodels.tools.eval_measures.rmse(x1, x2, axis=0)
rmse = rmse(compare['Observa-Dittos'], compare['Predeci-Dittos'], axis=0)

print(f'El Root Mean Square Error que tenemos entre Observa-Dittos y Predeci-Dittos es de {rmse}')
# Out:
# El Root Mean Square Error que tenemos entre Observa-Dittos y Predeci-Dittos es de 0.0938321696527326
