# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# Import numpy and pandas
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

import pylab
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
from pandas.plotting import lag_plot
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import adfuller
from statsmodels.tools.eval_measures import rmse

# %matplotlib inline

# %% [markdown]
# # Challenge 1 - Loading and Evaluating The Data
#
# In this lab, we will look at a dataset of sensor data from a cellular phone. The phone was carried in the subject's pocket for a few minutes while they walked around.
#
# To load the data, run the code below.

# %%
# Run this code:

sensor = pd.read_csv('../sub_1.csv')
sensor.drop(columns = ['Unnamed: 0'], inplace = True)

# %% [markdown]
# Examine the data using the `head` function.

# %%
# Your code here:
sensor.head()
sensor.shape
# Out:
#    attitude.roll  attitude.pitch  attitude.yaw  gravity.x  gravity.y  \
# 0       1.528132       -0.733896      0.696372   0.741895   0.669768
# 1       1.527992       -0.716987      0.677762   0.753099   0.657116
# 2       1.527765       -0.706999      0.670951   0.759611   0.649555
# 3       1.516768       -0.704678      0.675735   0.760709   0.647788
# 4       1.493941       -0.703918      0.672994   0.760062   0.647210
#
#    gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# 0  -0.031672        0.316738        0.778180        1.082764
# 1  -0.032255        0.842032        0.424446        0.643574
# 2  -0.032707       -0.138143       -0.040741        0.343563
# 3  -0.041140       -0.025005       -1.048717        0.035860
# 4  -0.058530        0.114253       -0.912890        0.047341
#
#    userAcceleration.x  userAcceleration.y  userAcceleration.z
# 0            0.294894           -0.184493            0.377542
# ...

# %% [markdown]
# Check whether there is any missing data. If there is any missing data, remove the rows containing missing data.

# %%
# Your code here:
sensor.isnull().sum()
# Out:
# attitude.roll         0
# attitude.pitch        0
# attitude.yaw          0
# gravity.x             0
# gravity.y             0
# gravity.z             0
# rotationRate.x        0
# rotationRate.y        0
# rotationRate.z        0
# userAcceleration.x    0
# userAcceleration.y    0
# userAcceleration.z    0
# dtype: int64

# %% [markdown]
# How many rows and columns are in our data?

# %%
# Your code here:
sensor.shape
# Out:
# (1751, 12)

# %% [markdown]
# To perform time series analysis on the data, we must change the index from a range index to a time series index. In the cell below, create a time series index using the `pd.date_range` function. Create a time series index starting at 1/1/2018 00:00:00 and ending at 1/1/2018 00:29:10. The number of periods is equal to the number of rows in `sensor`. The frequency should be set to `infer`.

# %%
# Your code here:
periods = (29 * 60) + 11
timestamps = pd.date_range(start = '01/01/2018 00:00:00', end = '01/01/2018 00:29:10', periods = periods)
timestamps
# Out:
# DatetimeIndex(['2018-01-01 00:00:00', '2018-01-01 00:00:01',
#                '2018-01-01 00:00:02', '2018-01-01 00:00:03',
#                '2018-01-01 00:00:04', '2018-01-01 00:00:05',
#                '2018-01-01 00:00:06', '2018-01-01 00:00:07',
#                '2018-01-01 00:00:08', '2018-01-01 00:00:09',
#                ...
#                '2018-01-01 00:29:01', '2018-01-01 00:29:02',
#                '2018-01-01 00:29:03', '2018-01-01 00:29:04',
#                '2018-01-01 00:29:05', '2018-01-01 00:29:06',
#                '2018-01-01 00:29:07', '2018-01-01 00:29:08',
#                '2018-01-01 00:29:09', '2018-01-01 00:29:10'],
#               dtype='datetime64[ns]', length=1751, freq=None)

# %% [markdown]
# Assign the time series index to the dataframe's index.

# %%
# Your code here:
sensor.set_index(timestamps, inplace = True)
sensor.head()
# Out:
#                      attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 2018-01-01 00:00:00       1.528132       -0.733896      0.696372   0.741895
# 2018-01-01 00:00:01       1.527992       -0.716987      0.677762   0.753099
# 2018-01-01 00:00:02       1.527765       -0.706999      0.670951   0.759611
# 2018-01-01 00:00:03       1.516768       -0.704678      0.675735   0.760709
# 2018-01-01 00:00:04       1.493941       -0.703918      0.672994   0.760062
#
#                      gravity.y  gravity.z  rotationRate.x  rotationRate.y  \
# 2018-01-01 00:00:00   0.669768  -0.031672        0.316738        0.778180
# 2018-01-01 00:00:01   0.657116  -0.032255        0.842032        0.424446
# 2018-01-01 00:00:02   0.649555  -0.032707       -0.138143       -0.040741
# 2018-01-01 00:00:03   0.647788  -0.041140       -0.025005       -1.048717
# 2018-01-01 00:00:04   0.647210  -0.058530        0.114253       -0.912890
#
# ...

# %% [markdown]
# Our next step is to decompose the time series and evaluate the patterns in the data. Load the `statsmodels.api` submodule and plot the decomposed plot of `userAcceleration.x`. Set `freq=60` in the `seasonal_decompose` function. Your graph should look like the one below.
#
# ![time series decomposition](../images/tsa_decompose.png)

# %%
# Your code here:
pylab.rcParams['figure.figsize'] = (16, 8)
res = sm.tsa.seasonal_decompose(sensor['userAcceleration.x'], period = 60)
res_plot = res.plot()

# %% [markdown]
# Plot the decomposed time series of `rotationRate.x` also with a frequency of 60.

# %%
pylab.rcParams['figure.figsize'] = (16, 8)
res = sm.tsa.seasonal_decompose(sensor['rotationRate.x'], period = 60)
res_plot = res.plot()

# %% [markdown]
# # Challenge 2 - Modelling the Data
#
# To model our data, we should look at a few assumptions. First, let's plot the `lag_plot` to detect any autocorrelation. Do this for `userAcceleration.x`

# %%
# Your code here:
lag_plot(sensor['userAcceleration.x'])

# %% [markdown]
# Create a lag plot for `rotationRate.x`

# %%
# Your code here:
lag_plot(sensor['rotationRate.x'])

# %% [markdown]
# What are your conclusions from both visualizations?

# %% [markdown]
# There seems to be a moderate autocorrelation based on the lagged values and the data seems pretty linear.
#  - https://www.itl.nist.gov/div898/handbook/eda/section3/lagplot.htm
#  - https://ncss-wpengine.netdna-ssl.com/wp-content/themes/ncss/pdf/Procedures/NCSS/Lag_Plots.pdf

# %% [markdown]
# The next step will be to test both variables for stationarity. Perform the Augmented Dickey Fuller test on both variables below.

# %%
# Your code here:
result = adfuller(sensor['userAcceleration.x'], autolag = None)

print(f'ADF Statistic: {result[0]}')
print(f'n_lags: {result[1]}')
print(f'p-value: {result[1]}')
for key, value in result[4].items():
    print('Critial Values:')
    print(f'   {key}, {value}')
# Out:
# ADF Statistic: -8.160095026835926
# n_lags: 9.193147705719152e-13
# p-value: 9.193147705719152e-13
# Critial Values:
#    1%, -3.4341465551936534
# Critial Values:
#    5%, -2.863216966926812
# Critial Values:
#    10%, -2.567662770090317

# %%
result = adfuller(sensor['rotationRate.x'], autolag = None)

print(f'ADF Statistic: {result[0]}')
print(f'n_lags: {result[1]}')
print(f'p-value: {result[1]}')
for key, value in result[4].items():
    print('Critial Values:')
    print(f'   {key}, {value}')
# Out:
# ADF Statistic: -5.269860625086423
# n_lags: 6.320230335912132e-06
# p-value: 6.320230335912132e-06
# Critial Values:
#    1%, -3.4341465551936534
# Critial Values:
#    5%, -2.863216966926812
# Critial Values:
#    10%, -2.567662770090317

# %% [markdown]
# What are your conclusions from this test?

# %% [markdown]
# We can reject the null hypothesis as the p-value is less than 0.05 and we can say that the series is stationary.
#  - https://www.machinelearningplus.com/time-series/augmented-dickey-fuller-test/

# %%
fig, axes = plt.subplots(figsize = (16, 8))
plt.plot(sensor['userAcceleration.x'])
plt.title('User Acceleration')
# Out:
# Text(0.5, 1.0, 'User Acceleration')

# %%
fig, axes = plt.subplots(figsize = (16, 8))
plt.plot(sensor['rotationRate.x'])
plt.title('Rotation Rate')
# Out:
# Text(0.5, 1.0, 'Rotation Rate')

# %% [markdown]
# Finally, we'll create an ARMA model for `userAcceleration.x`. Load the `ARIMA` function from `statsmodels`. The order of the model is (2, 1). Split the data to train and test. Use the last 10 observations as the test set and all other observations as the training set.

# %%
# Your code here:
training_data = sensor['userAcceleration.x'] #[:-10]
#test_data = sensor['userAcceleration.x'][-10:]

model = ARIMA(training_data, order = (2, 1, 0), freq = 'S')
model_fit = model.fit()
print(model_fit.summary())

test_output = model_fit.predict(len(training_data) - 10, len(training_data) - 1, freq = 'S')
test_output
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:     userAcceleration.x   No. Observations:                 1751
# Model:                 ARIMA(2, 1, 0)   Log Likelihood                 207.553
# Date:                Sun, 24 Jan 2021   AIC                           -409.106
# Time:                        15:14:24   BIC                           -392.703
# Sample:                    01-01-2018   HQIC                          -403.042
#                          - 01-01-2018
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.4039      0.014     28.581      0.000       0.376       0.432
# ar.L2         -0.3207      0.017    -18.739      0.000      -0.354      -0.287
# sigma2         0.0462      0.001     51.710      0.000       0.044       0.048
# ...

# %% [markdown]
# - https://machinelearningmastery.com/arima-for-time-series-forecasting-with-python/
# - https://www.geeksforgeeks.org/python-arima-model-for-time-series-forecasting/

# %% [markdown]
# To compare our predictions with the observed data, we can compute the RMSE (Root Mean Squared Error) from the submodule `statsmodels.tools.eval_measures`. You can read more about this function [here](https://www.statsmodels.org/dev/generated/statsmodels.tools.eval_measures.rmse.html). Compute the RMSE for the last 10 rows of the data by comparing the observed and predicted data for the `userAcceleration.x` column.

# %%
# Your code here:
rmse_model = rmse(test_output, sensor['userAcceleration.x'][-10:], axis = 0)
rmse_model
# Out:
# 0.09157314465358088

# %% [markdown]
# - RMSE is a measure of how spread out these residuals are. In other words, it tells you how concentrated the data is around the line of best fit. (https://www.statisticshowto.com/probability-and-statistics/regression-analysis/rmse-root-mean-square-error/)
