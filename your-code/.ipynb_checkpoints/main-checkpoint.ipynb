# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# Import numpy and pandas

import numpy as np
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-61-40d6851806f1> in <module>
#       3 import numpy as np
#       4 import pandas as pd
# ----> 5 from pandas.tools.plotting import lag_plot
#
# ModuleNotFoundError: No module named 'pandas.tools'

# %% [markdown]
# # Challenge 1 - Loading and Evaluating The Data
#
# In this lab, we will look at a dataset of sensor data from a cellular phone. The phone was carried in the subject's pocket for a few minutes while they walked around.
#
# To load the data, run the code below.

# %%
# Run this code:

sensor = pd.read_csv('../sub_1.csv')
sensor.drop(columns=['Unnamed: 0'], inplace=True)

# %% [markdown]
# Examine the data using the `head` function.

# %%
# Your code here:
sensor.head()
# Out:
#    attitude.roll  attitude.pitch  attitude.yaw  gravity.x  gravity.y  \
# 0       1.528132       -0.733896      0.696372   0.741895   0.669768
# 1       1.527992       -0.716987      0.677762   0.753099   0.657116
# 2       1.527765       -0.706999      0.670951   0.759611   0.649555
# 3       1.516768       -0.704678      0.675735   0.760709   0.647788
# 4       1.493941       -0.703918      0.672994   0.760062   0.647210
#
#    gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# 0  -0.031672        0.316738        0.778180        1.082764
# 1  -0.032255        0.842032        0.424446        0.643574
# 2  -0.032707       -0.138143       -0.040741        0.343563
# 3  -0.041140       -0.025005       -1.048717        0.035860
# 4  -0.058530        0.114253       -0.912890        0.047341
#
#    userAcceleration.x  userAcceleration.y  userAcceleration.z
# 0            0.294894           -0.184493            0.377542
# ...

# %% [markdown]
# Check whether there is any missing data. If there is any missing data, remove the rows containing missing data.

# %%
# Your code here:
sensor.dropna(inplace=True)
sensor.shape
# Out:
# (1751, 12)

# %% [markdown]
# How many rows and columns are in our data?

# %% [markdown]
# ## Your code here:
#
# There are 1751 rows with 12 columns
#
# --------------

# %% [markdown]
# To perform time series analysis on the data, we must change the index from a range index to a time series index. In the cell below, create a time series index using the `pd.date_range` function. Create a time series index starting at 1/1/2018 00:00:00 and ending at 1/1/2018 00:29:10. The number of periods is equal to the number of rows in `sensor`. The frequency should be set to `infer`.

# %%
# Your code here:

date_time=pd.date_range(start='1/1/2018 00:00:00', end='1/08/2018 00:29:10', periods=1751)
sensor.insert(0,'Date Time', date_time)

# %%
sensor
# Out:
#                    Date Time  attitude.roll  attitude.pitch  attitude.yaw  \
# 0    2018-01-01 00:00:00.000       1.528132       -0.733896      0.696372
# 1    2018-01-01 00:05:46.600       1.527992       -0.716987      0.677762
# 2    2018-01-01 00:11:33.200       1.527765       -0.706999      0.670951
# 3    2018-01-01 00:17:19.800       1.516768       -0.704678      0.675735
# 4    2018-01-01 00:23:06.400       1.493941       -0.703918      0.672994
# ...                      ...            ...             ...           ...
# 1746 2018-01-08 00:06:03.600       1.797120       -0.562324      2.445889
# 1747 2018-01-08 00:11:50.200       1.814297       -0.569719      2.449655
# 1748 2018-01-08 00:17:36.800       1.830821       -0.578367      2.447967
# 1749 2018-01-08 00:23:23.400       1.849557       -0.586962      2.439458
# 1750 2018-01-08 00:29:10.000       1.869375       -0.596783      2.433775
#
#       gravity.x  gravity.y  gravity.z  rotationRate.x  rotationRate.y  \
# ...

# %% [markdown]
# Assign the time series index to the dataframe's index.

# %%
# Your code here:

sensor.set_index(['Date Time'], inplace=True)  #set_index es para definir que columna o array se usará como index, por default borra el index previo
sensor
# Out:
#                          attitude.roll  attitude.pitch  attitude.yaw  \
# Date Time
# 2018-01-01 00:00:00.000       1.528132       -0.733896      0.696372
# 2018-01-01 00:05:46.600       1.527992       -0.716987      0.677762
# 2018-01-01 00:11:33.200       1.527765       -0.706999      0.670951
# 2018-01-01 00:17:19.800       1.516768       -0.704678      0.675735
# 2018-01-01 00:23:06.400       1.493941       -0.703918      0.672994
# ...                                ...             ...           ...
# 2018-01-08 00:06:03.600       1.797120       -0.562324      2.445889
# 2018-01-08 00:11:50.200       1.814297       -0.569719      2.449655
# 2018-01-08 00:17:36.800       1.830821       -0.578367      2.447967
# 2018-01-08 00:23:23.400       1.849557       -0.586962      2.439458
# 2018-01-08 00:29:10.000       1.869375       -0.596783      2.433775
#
#                          gravity.x  gravity.y  gravity.z  rotationRate.x  \
# Date Time
# ...

# %% [markdown]
# Our next step is to decompose the time series and evaluate the patterns in the data. Load the `statsmodels.api` submodule and plot the decomposed plot of `userAcceleration.x`. Set `freq=60` in the `seasonal_decompose` function. Your graph should look like the one below.
#
# ![time series decomposition](../images/tsa_decompose.png)

# %%
import statsmodels.api as sm

# %%
# Your code here:
y=sensor['userAcceleration.x']

decomposition = sm.tsa.seasonal_decompose(y,model='additive', period=60)

# %%
import matplotlib.pyplot as plt

# %%
plt.rcParams['figure.figsize'] =11,8
fig=decomposition.plot()

# %% [markdown]
# Plot the decomposed time series of `rotationRate.x` also with a frequency of 60.

# %%
y2=sensor['rotationRate.x']

decomposition2 = sm.tsa.seasonal_decompose(y2,model='additive', period=60)

# %%
plt.rcParams['figure.figsize'] =11,8
fig=decomposition2.plot()

# %% [markdown]
# # Challenge 2 - Modelling the Data
#
# To model our data, we should look at a few assumptions. First, let's plot the `lag_plot` to detect any autocorrelation. Do this for `userAcceleration.x`

# %%
from pandas.plotting import lag_plot

# %%
# Your code here
lag_plot(sensor['userAcceleration.x'], lag=1)

# %% [markdown]
# Create a lag plot for `rotationRate.x`

# %%
# Your code here:
lag_plot(sensor['rotationRate.x'], lag=1)

# %% [markdown]
# What are your conclusions from both visualizations?

# %% [markdown]
# # Your conclusions here:
#
# There is a clear linear correlation between the current value and the previus value for both parametsrs in our time series

# %% [markdown]
# The next step will be to test both variables for stationarity. Perform the Augmented Dickey Fuller test on both variables below.

# %%
from statsmodels.tsa.stattools import adfuller

# %%
# Your code here for Acceleration:
ADFacc=adfuller(sensor['userAcceleration.x'])
userAcceleration_pvalue=ADFacc[1]

print('The P value of userAcceleration is',userAcceleration_pvalue )

# Your code here for Rotation:


ADFrot=adfuller(sensor['rotationRate.x'])
userRotation_pvalue=ADFrot[1]

print('The P value of userAcceleration is',userRotation_pvalue )
# Out:
# The P value of userAcceleration is 2.823439483037483e-30
# The P value of userAcceleration is 6.320230335912449e-06

# %% [markdown]
# What are your conclusions from this test?

# %% [markdown]
# # Your conclusions here:
#
# Since for both parameters the p value is so low (rejecting the null hypothesis) we can confidently say that the data indeed is stationary

# %% [markdown]
# Finally, we'll create an ARMA model for `userAcceleration.x`. Load the `ARMA` function from `statsmodels`. The order of the model is (2, 1). Split the data to train and test. Use the last 10 observations as the test set and all other observations as the training set.

# %%
from statsmodels.tsa.arima_model import ARMA

# %%
# Your code here:

#lETS CREATE OUR FIT MODEL

train=sensor['userAcceleration.x'][:-10]
test=sensor['userAcceleration.x'][-10:]

model = ARMA(sensor['userAcceleration.x'], order=(2, 1), freq=60)
model_fit = model.fit(disp=False)

# NOW LETS MAKE A PREDICTION

predictions = model_fit.predict(len(train), len(train)+len(test)-1)
# Out:
# C:\Users\User\ANACONDA3.7\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency 346600L will be used.
#   % freq, ValueWarning)

# %%
# Aquí comparamos los valores observados contra los predichos por el modelo
# Notese que los modelos observados evaluados son los ultimos 10, para hacer match con los 10 predecidos

eval=pd.DataFrame({'observed': sensor['userAcceleration.x'][-10:], 'predicted': predictions})  
eval
# Out:
#                          observed  predicted
# 2018-01-07 23:37:10.600  0.149749   0.172776
# 2018-01-07 23:42:57.200  0.038461   0.115159
# 2018-01-07 23:48:43.800 -0.169175  -0.008270
# 2018-01-07 23:54:30.400 -0.300361  -0.186762
# 2018-01-08 00:00:17.000 -0.270174  -0.229211
# 2018-01-08 00:06:03.600 -0.268367  -0.136440
# 2018-01-08 00:11:50.200 -0.102444  -0.162658
# 2018-01-08 00:17:36.800 -0.085590   0.035719
# 2018-01-08 00:23:23.400 -0.048105  -0.043530
# 2018-01-08 00:29:10.000 -0.065011   0.008415

# %% [markdown]
# To compare our predictions with the observed data, we can compute the RMSE (Root Mean Squared Error) from the submodule `statsmodels.tools.eval_measures`. You can read more about this function [here](https://www.statsmodels.org/dev/generated/statsmodels.tools.eval_measures.rmse.html). Compute the RMSE for the last 10 rows of the data by comparing the observed and predicted data for the `userAcceleration.x` column.

# %%
# Your code here:
# Evaluamos con Root Mean Squared Error

sm.tools.eval_measures.rmse(eval.observed, eval.predicted, axis=0)
# Out:
# 0.09383216682141077

# %% [markdown]
# #### Tenemos un error cercano al 10 por ciento entre nuestro observado y el predicho
