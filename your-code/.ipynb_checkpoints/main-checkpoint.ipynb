# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# Import numpy and pandas
import pandas as pd
import numpy as np

# %% [markdown]
# # Challenge 1 - Loading and Evaluating The Data
#
# In this lab, we will look at a dataset of sensor data from a cellular phone. The phone was carried in the subject's pocket for a few minutes while they walked around.
#
# To load the data, run the code below.

# %%
# Run this code:

sensor = pd.read_csv('../sub_1.csv')
sensor.drop(columns=['Unnamed: 0'], inplace=True)

# %% [markdown]
# Examine the data using the `head` function.

# %%
# Your code here:
sensor.head()
# Out:
#    attitude.roll  attitude.pitch  attitude.yaw  gravity.x  gravity.y  \
# 0       1.528132       -0.733896      0.696372   0.741895   0.669768
# 1       1.527992       -0.716987      0.677762   0.753099   0.657116
# 2       1.527765       -0.706999      0.670951   0.759611   0.649555
# 3       1.516768       -0.704678      0.675735   0.760709   0.647788
# 4       1.493941       -0.703918      0.672994   0.760062   0.647210
#
#    gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# 0  -0.031672        0.316738        0.778180        1.082764
# 1  -0.032255        0.842032        0.424446        0.643574
# 2  -0.032707       -0.138143       -0.040741        0.343563
# 3  -0.041140       -0.025005       -1.048717        0.035860
# 4  -0.058530        0.114253       -0.912890        0.047341
#
#    userAcceleration.x  userAcceleration.y  userAcceleration.z
# 0            0.294894           -0.184493            0.377542
# ...

# %% [markdown]
# Check whether there is any missing data. If there is any missing data, remove the rows containing missing data.

# %%
# Your code here:
sensor.isnull().sum()
#There is no missing data.
# Out:
# attitude.roll         0
# attitude.pitch        0
# attitude.yaw          0
# gravity.x             0
# gravity.y             0
# gravity.z             0
# rotationRate.x        0
# rotationRate.y        0
# rotationRate.z        0
# userAcceleration.x    0
# userAcceleration.y    0
# userAcceleration.z    0
# dtype: int64

# %% [markdown]
# How many rows and columns are in our data?

# %%
# Your code here:
sensor.shape

#There are 1751 rows and 12 columns
# Out:
# (1751, 12)

# %% [markdown]
# To perform time series analysis on the data, we must change the index from a range index to a time series index. In the cell below, create a time series index using the `pd.date_range` function. Create a time series index starting at 1/1/2018 00:00:00 and ending at 1/1/2018 00:29:10. The number of periods is equal to the number of rows in `sensor`. The frequency should be set to `infer`.

# %%
# Your code here:
sensor['TimeStamp'] = pd.date_range(start = '1/1/2018 00:00:00', end = '1/1/2018 00:29:10', periods = len(sensor))

#With the above code we're explicitly stating that we want 1751 periods
#We could also do it if we state a frequency of 'S' which stands for secondly, given that there are 1751 steps between dates
# sensor['TimeStamp'] = pd.date_range(start = '1/1/2018 00:00:00', end = '1/1/2018 00:29:10', freq = 'S')
sensor
# Out:
#       attitude.roll  attitude.pitch  attitude.yaw  gravity.x  gravity.y  \
# 0          1.528132       -0.733896      0.696372   0.741895   0.669768
# 1          1.527992       -0.716987      0.677762   0.753099   0.657116
# 2          1.527765       -0.706999      0.670951   0.759611   0.649555
# 3          1.516768       -0.704678      0.675735   0.760709   0.647788
# 4          1.493941       -0.703918      0.672994   0.760062   0.647210
# ...             ...             ...           ...        ...        ...
# 1746       1.797120       -0.562324      2.445889   0.824443   0.533154
# 1747       1.814297       -0.569719      2.449655   0.817212   0.539396
# 1748       1.830821       -0.578367      2.447967   0.809207   0.546658
# 1749       1.849557       -0.586962      2.439458   0.800485   0.553834
# 1750       1.869375       -0.596783      2.433775   0.790551   0.561984
#
#       gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# ...

# %% [markdown]
# Assign the time series index to the dataframe's index.

# %%
# Your code here:
sensor.set_index('TimeStamp', inplace=True)
sensor
# Out:
#                      attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# TimeStamp
# 2018-01-01 00:00:00       1.528132       -0.733896      0.696372   0.741895
# 2018-01-01 00:00:01       1.527992       -0.716987      0.677762   0.753099
# 2018-01-01 00:00:02       1.527765       -0.706999      0.670951   0.759611
# 2018-01-01 00:00:03       1.516768       -0.704678      0.675735   0.760709
# 2018-01-01 00:00:04       1.493941       -0.703918      0.672994   0.760062
# ...                            ...             ...           ...        ...
# 2018-01-01 00:29:06       1.797120       -0.562324      2.445889   0.824443
# 2018-01-01 00:29:07       1.814297       -0.569719      2.449655   0.817212
# 2018-01-01 00:29:08       1.830821       -0.578367      2.447967   0.809207
# 2018-01-01 00:29:09       1.849557       -0.586962      2.439458   0.800485
# 2018-01-01 00:29:10       1.869375       -0.596783      2.433775   0.790551
#
# ...

# %% [markdown]
# Our next step is to decompose the time series and evaluate the patterns in the data. Load the `statsmodels.api` submodule and plot the decomposed plot of `userAcceleration.x`. Set `freq=60` in the `seasonal_decompose` function. Your graph should look like the one below.
#
# ![time series decomposition](../images/tsa_decompose.png)

# %%
# Your code here:
import statsmodels.api as sm
import matplotlib.pyplot as plt
# %matplotlib inline

TimeSeries = sm.tsa.seasonal_decompose(sensor['userAcceleration.x'], freq=60)

TimeSeriesplot = TimeSeries.plot()

# %% [markdown]
# Plot the decomposed time series of `rotationRate.x` also with a frequency of 60.

# %%
TimeSeries2 = sm.tsa.seasonal_decompose(sensor['rotationRate.x'], freq=60)

TimeSeriesplot2 = TimeSeries2.plot()

# %% [markdown]
# # Challenge 2 - Modelling the Data
#
# To model our data, we should look at a few assumptions. First, let's plot the `lag_plot` to detect any autocorrelation. Do this for `userAcceleration.x`

# %%
# Your code here:
from pandas.plotting import lag_plot
lag_plot(sensor['userAcceleration.x']);

#the ';' at the end of the previous code eliminates the <matplotlib.axes._subplots.AxesSubplot at 0x1564a437b48> message that would appear on top of the graph

# %% [markdown]
# Create a lag plot for `rotationRate.x`

# %%
# Your code here:
lag_plot(sensor['rotationRate.x']);

# %% [markdown]
# What are your conclusions from both visualizations?

# %%
# Your conclusions here:
#There is a linear relationship that would entail autocorrelation, although with a significant number of outliers.

# %% [markdown]
# The next step will be to test both variables for stationarity. Perform the Augmented Dickey Fuller test on both variables below.

# %%
# Your code here:
from statsmodels.tsa.stattools import adfuller

#Testing for userAcceleration.x
print(adfuller(sensor['userAcceleration.x'])[1]) #This provides us with the second [1] value which is the Pvalue

#Testing for rorationRate.x
print(adfuller(sensor['rotationRate.x'])[1]) 

#Considering the following:
#H0-the data is not stationary
#H1-the data IS stationary

#And Given that both pvalues are well below 0.05 one can safely reject H0 and thus both are considered stationary
# Out:
# 2.823439483037483e-30
# 6.3202303359124956e-06

# %% [markdown]
# What are your conclusions from this test?

# %%
# Your conclusions here:
#Considering the following:
#H0-the data is not stationary
#H1-the data IS stationary

#And Given that both pvalues are well below 0.05 one can safely reject H0 and thus both are considered stationary

# %% [markdown]
# Finally, we'll create an ARMA model for `userAcceleration.x`. Load the `ARMA` function from `statsmodels`. The order of the model is (2, 1). Split the data to train and test. Use the last 10 observations as the test set and all other observations as the training set.

# %%
# Your code here:
from statsmodels.tsa.arima_model import ARMA

train, test = sensor['userAcceleration.x'][:-10],sensor['userAcceleration.x'][-10:] #The first part [:-10] of the code includes all of the rows, except for the last 10 entries, into the train dataFrame
model = ARMA(train, order=(2,1)).fit()

#make prediction
prediction = model.predict(len(train), len(sensor['userAcceleration.x'])-1)

#Intenté con el código que viene en el learning, sin embargo me brincó error respecto a diferentes longitudes:
#predictions = model_fit.predict(len(sensor['userAcceleration.x'])-3), len(sensor['userAcceleration.x'])-1)

res =  pd.DataFrame({'Real':test, 'Prediction':prediction})
res
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency S will be used.
#   % freq, ValueWarning)
#                          Real  Prediction
# 2018-01-01 00:29:01  0.149749    0.173149
# 2018-01-01 00:29:02  0.038461    0.142896
# 2018-01-01 00:29:03 -0.169175    0.100522
# 2018-01-01 00:29:04 -0.300361    0.070106
# 2018-01-01 00:29:05 -0.270174    0.056099
# 2018-01-01 00:29:06 -0.268367    0.053778
# 2018-01-01 00:29:07 -0.102444    0.056790
# 2018-01-01 00:29:08 -0.085590    0.060646
# 2018-01-01 00:29:09 -0.048105    0.063316
# 2018-01-01 00:29:10 -0.065011    0.064493

# %% [markdown]
# To compare our predictions with the observed data, we can compute the RMSE (Root Mean Squared Error) from the submodule `statsmodels.tools.eval_measures`. You can read more about this function [here](https://www.statsmodels.org/dev/generated/statsmodels.tools.eval_measures.rmse.html). Compute the RMSE for the last 10 rows of the data by comparing the observed and predicted data for the `userAcceleration.x` column.

# %%
# Your code here:
import statsmodels.tools.eval_measures
statsmodels.tools.eval_measures.rmse(test, prediction, axis=0)
# Out:
# 0.22529864281267614
