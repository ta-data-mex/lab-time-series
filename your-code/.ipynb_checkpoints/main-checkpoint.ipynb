# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# Import numpy and pandas
import numpy as np
import pandas as pd

# %% [markdown]
# # Challenge 1 - Loading and Evaluating The Data
#
# In this lab, we will look at a dataset of sensor data from a cellular phone. The phone was carried in the subject's pocket for a few minutes while they walked around.
#
# To load the data, run the code below.

# %%
# Run this code:
sensor = pd.read_csv('../sub_1.csv')
sensor.drop(columns=['Unnamed: 0'], inplace=True)

# %% [markdown]
# Examine the data using the `head` function.

# %%
# Your code here:
sensor.head()
# Out:
#    attitude.roll  attitude.pitch  attitude.yaw  gravity.x  gravity.y  \
# 0       1.528132       -0.733896      0.696372   0.741895   0.669768
# 1       1.527992       -0.716987      0.677762   0.753099   0.657116
# 2       1.527765       -0.706999      0.670951   0.759611   0.649555
# 3       1.516768       -0.704678      0.675735   0.760709   0.647788
# 4       1.493941       -0.703918      0.672994   0.760062   0.647210
#
#    gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# 0  -0.031672        0.316738        0.778180        1.082764
# 1  -0.032255        0.842032        0.424446        0.643574
# 2  -0.032707       -0.138143       -0.040741        0.343563
# 3  -0.041140       -0.025005       -1.048717        0.035860
# 4  -0.058530        0.114253       -0.912890        0.047341
#
#    userAcceleration.x  userAcceleration.y  userAcceleration.z
# 0            0.294894           -0.184493            0.377542
# ...

# %% [markdown]
# Check whether there is any missing data. If there is any missing data, remove the rows containing missing data.

# %%
# Your code here:
sensor.isnull().sum()
# Out:
# attitude.roll         0
# attitude.pitch        0
# attitude.yaw          0
# gravity.x             0
# gravity.y             0
# gravity.z             0
# rotationRate.x        0
# rotationRate.y        0
# rotationRate.z        0
# userAcceleration.x    0
# userAcceleration.y    0
# userAcceleration.z    0
# dtype: int64

# %% [markdown]
# How many rows and columns are in our data?

# %%
# Your code here:
sensor.shape[0]
# Out:
# 1751

# %% [markdown]
# To perform time series analysis on the data, we must change the index from a range index to a time series index. In the cell below, create a time series index using the `pd.date_range` function. Create a time series index starting at 1/1/2018 00:00:00 and ending at 1/1/2018 00:29:10. The number of periods is equal to the number of rows in `sensor`. The frequency should be set to `infer`.

# %%
# Your code here:
pd.date_range(start='1/1/2018 00:00:00', end='1/1/2018 00:29:10', periods=sensor.shape[0])
# Out:
# DatetimeIndex(['2018-01-01 00:00:00', '2018-01-01 00:00:01',
#                '2018-01-01 00:00:02', '2018-01-01 00:00:03',
#                '2018-01-01 00:00:04', '2018-01-01 00:00:05',
#                '2018-01-01 00:00:06', '2018-01-01 00:00:07',
#                '2018-01-01 00:00:08', '2018-01-01 00:00:09',
#                ...
#                '2018-01-01 00:29:01', '2018-01-01 00:29:02',
#                '2018-01-01 00:29:03', '2018-01-01 00:29:04',
#                '2018-01-01 00:29:05', '2018-01-01 00:29:06',
#                '2018-01-01 00:29:07', '2018-01-01 00:29:08',
#                '2018-01-01 00:29:09', '2018-01-01 00:29:10'],
#               dtype='datetime64[ns]', length=1751, freq=None)

# %% [markdown]
# Assign the time series index to the dataframe's index.

# %%
# Your code here:
sensor=sensor.set_index(pd.date_range(start='1/1/2018 00:00:00', end='1/1/2018 00:29:10', periods=sensor.shape[0]))
sensor.head()
# Out:
#                      attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 2018-01-01 00:00:00       1.528132       -0.733896      0.696372   0.741895
# 2018-01-01 00:00:01       1.527992       -0.716987      0.677762   0.753099
# 2018-01-01 00:00:02       1.527765       -0.706999      0.670951   0.759611
# 2018-01-01 00:00:03       1.516768       -0.704678      0.675735   0.760709
# 2018-01-01 00:00:04       1.493941       -0.703918      0.672994   0.760062
#
#                      gravity.y  gravity.z  rotationRate.x  rotationRate.y  \
# 2018-01-01 00:00:00   0.669768  -0.031672        0.316738        0.778180
# 2018-01-01 00:00:01   0.657116  -0.032255        0.842032        0.424446
# 2018-01-01 00:00:02   0.649555  -0.032707       -0.138143       -0.040741
# 2018-01-01 00:00:03   0.647788  -0.041140       -0.025005       -1.048717
# 2018-01-01 00:00:04   0.647210  -0.058530        0.114253       -0.912890
#
# ...

# %%
# Our next step is to decompose the time series and evaluate the patterns in the data. Load the `statsmodels.api` submodule and plot the decomposed plot of `userAcceleration.x`. Set `freq=60` in the `seasonal_decompose` function. Your graph should look like the one below.

![time series decomposition](../images/tsa_decompose.png)
# Out:
# '[time' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# Your code here:
import statsmodels.api as sm
from statsmodels.tsa.seasonal import seasonal_decompose

seasonal_decompose(sensor['userAcceleration.x'], freq=60).plot().show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   after removing the cwd from sys.path.

# %% [markdown]
# Plot the decomposed time series of `rotationRate.x` also with a frequency of 60.

# %% [markdown]
# # Challenge 2 - Modelling the Data
#
# To model our data, we should look at a few assumptions. First, let's plot the `lag_plot` to detect any autocorrelation. Do this for `userAcceleration.x`

# %%
# Your code here:
import matplotlib.pyplot as plt
for i in range(1,4):
    plt.subplot(1,3,i)
    pd.plotting.lag_plot(sensor['userAcceleration.x'], lag=i)
plt.show()


#diagrama de retraso 1

# %% [markdown]
# Create a lag plot for `rotationRate.x`

# %%
# Your code here:
for i in range(1,4):
    plt.subplot(1,3,i)
    pd.plotting.lag_plot(sensor['rotationRate.x'],lag=i)
plt.show()

# %% [markdown]
# What are your conclusions from both visualizations?

# %%
# Your conclusions here:
#Observamos que graficando el tiempo de retraso y(t-n); n=1,2,3 donde n es el retraso hay una autocorrelacion en las, 
#en las dos variables, aunque cuando el tiempo de retraso aumenta se va perdiendo la auto correlación.
#Para un análisis podemos graficar los n_lags y observar como va disminuyendo la autocorrelación, por ejemplo
#para un lag de 7 se pierde completamente la autocorrelación sin embargo aumenta en el lag 16 y se vuelve constante

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(sensor['rotationRate.x'].values.squeeze(), lags=60, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(sensor['rotationRate.x'], lags=40, ax=ax2)

# %% [markdown]
# The next step will be to test both variables for stationarity. Perform the Augmented Dickey Fuller test on both variables below.

# %%
# Your code here:
print(sm.tsa.stattools.adfuller(sensor['userAcceleration.x']))
print(sm.tsa.stattools.adfuller(sensor['rotationRate.x']))
# Out:
# (-17.957994086169755, 2.823439483037483e-30, 4, 1746, {'1%': -3.434100824760071, '5%': -2.863196780129223, '10%': -2.5676520210882936}, -727.6140124402791)
# (-5.269860625086435, 6.320230335911768e-06, 25, 1725, {'1%': -3.4341465551936534, '5%': -2.863216966926812, '10%': -2.567662770090317}, 2619.6049719981947)

# %% [markdown]
# What are your conclusions from this test?

# %%
# Your conclusions here:
# Si tomamos el valor crítico de la prueba del test del 5 % observamos que nuestro p_value se encuentra en la derecha,
#es decir en la prueba de no rechazo por lo tanto la serie userAcceleration.x tiene una raiz unitaria porque no rechazamos
#la hipotesis nula

#Llegamos la conclusión que: NO ES ESTACIONARIA.

#El mismo análisis sería para la serie de rotationRate.x, inclusive el valor crítico se aleja mucho más que nuesto P value 
#por lo que no rechazamos la hipotesis nula

#También: NO ES ESTACIONARIA

# %% [markdown]
# Finally, we'll create an ARMA model for `userAcceleration.x`. Load the `ARMA` function from `statsmodels`. The order of the model is (2, 1). Split the data to train and test. Use the last 10 observations as the test set and all other observations as the training set.

# %%
# Your code here:
import warnings
warnings.filterwarnings("ignore")
arma_mod21 = sm.tsa.ARMA(sensor['userAcceleration.x'], (2,1)).fit(disp=False)
print(arma_mod21.params)
# Out:
# const                       0.062549
# ar.L1.userAcceleration.x    0.988781
# ar.L2.userAcceleration.x   -0.378779
# ma.L1.userAcceleration.x    0.182158
# dtype: float64

# %% [markdown]
# To compare our predictions with the observed data, we can compute the RMSE (Root Mean Squared Error) from the submodule `statsmodels.tools.eval_measures`. You can read more about this function [here](https://www.statsmodels.org/dev/generated/statsmodels.tools.eval_measures.rmse.html). Compute the RMSE for the last 10 rows of the data by comparing the observed and predicted data for the `userAcceleration.x` column.

# %%
# Your code here:
#sm.tools.eval_measures(arma_mod21,sensor['userAcceleration.x'])
ultimos10=sensor['userAcceleration.x'].tail(10)
prediccion = arma_mod21.predict( '2018-01-01 00:29:01', '2018-01-01 00:29:10',dynamic=True)
print('------------------PRIMER MODELO--------------------')
print(prediccion)
print('Error cuadratico medio:', sm.tools.eval_measures.rmse(ultimos10,prediccion))

#graficando nuestro modelo 
fig, ax = plt.subplots(figsize=(10, 5))
ax = sensor['userAcceleration.x'].loc['2018-01-01 00:28:36':].plot(ax=ax)#elegimos una tiempo más atras, para observar
fig = arma_mod21.plot_predict('2018-01-01 00:29:01', '2018-01-01 00:29:10', dynamic=True, ax=ax, plot_insample=False)

##Podemos hacer otro modelo para ver si puede mejorar##
print('------------------SEGUNDO MODELO--------------------')
arma_mod30 = sm.tsa.ARMA(sensor['userAcceleration.x'], (1,0)).fit(disp=False)
print(arma_mod30.params)
prediccion_2 = arma_mod30.predict( '2018-01-01 00:29:01', '2018-01-01 00:29:10',dynamic=True)
print(prediccion_2)
print('Error cuadratico medio:', sm.tools.eval_measures.rmse(ultimos10,prediccion_2))
fig, ax = plt.subplots(figsize=(10, 5))
ax = sensor['userAcceleration.x'].loc['2018-01-01 00:28:36':].plot(ax=ax)#elegimos una tiempo más atras, para observar
fig = arma_mod30.plot_predict('2018-01-01 00:29:01', '2018-01-01 00:29:10', dynamic=True, ax=ax, plot_insample=False)

#Mejora un poco con el modelo sm.tsa.ARMA(sensor['userAcceleration.x'], (1,0)).fit(disp=False)
# Out:
# ------------------PRIMER MODELO--------------------
# 2018-01-01 00:29:01    0.172776
# 2018-01-01 00:29:02    0.142123
# 2018-01-01 00:29:03    0.099478
# 2018-01-01 00:29:04    0.068923
# 2018-01-01 00:29:05    0.054863
# 2018-01-01 00:29:06    0.052535
# 2018-01-01 00:29:07    0.055558
# 2018-01-01 00:29:08    0.059430
# 2018-01-01 00:29:09    0.062113
# 2018-01-01 00:29:10    0.063299
# Freq: S, dtype: float64
# Error cuadratico medio: 0.224288874253415
# ------------------SEGUNDO MODELO--------------------
# const                       0.062681
# ar.L1.userAcceleration.x    0.759399
# dtype: float64
# 2018-01-01 00:29:01    0.121557
# 2018-01-01 00:29:02    0.107392
# 2018-01-01 00:29:03    0.096634
# 2018-01-01 00:29:04    0.088465
# 2018-01-01 00:29:05    0.082261
# 2018-01-01 00:29:06    0.077550
# 2018-01-01 00:29:07    0.073973
# 2018-01-01 00:29:08    0.071256
# 2018-01-01 00:29:09    0.069193
# 2018-01-01 00:29:10    0.067626
# Freq: S, dtype: float64
# ...
